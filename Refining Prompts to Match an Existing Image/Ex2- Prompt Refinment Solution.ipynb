# %%
# Important: Don't forget to update this

AZURE_OPENAI_API_KEY = "****"
AZURE_OPENAI_ENDPOINT = "***"

GPT_DEPLOYMENT = "gpt-4o"
GPT_VERSION = "2024-08-01-preview"
DALLE_DEPLOYMENT = "dall-e-3"
DALLE_VERSION = "2024-02-01"

# %%
import requests
from PIL import Image
from IPython.display import display

from utils import create_openai_client, generate_image

# %%
dalle = create_openai_client(DALLE_VERSION, AZURE_OPENAI_API_KEY, AZURE_OPENAI_ENDPOINT)

# %%
prompt = "A warm-toned close-up photograph of a single golden cookie with a textured surface, placed on a white napkin. The background features a glass jar filled with cookies, slightly out of focus, creating a shallow depth of field. Soft natural lighting illuminates the scene from the top left, casting gentle shadows and highlighting the cookie's texture. The setting has a cozy and rustic feel with crumbs visible on the napkin for added realism."

# %%
image_url = generate_image(
    dalle, prompt, DALLE_DEPLOYMENT, '1024x1024', 'hd', 'natural')
image_url
# Out:
# 'https://dalleproduse.blob.core.windows.net/private/images/c54a1ddf-4724-4a0f-be86-40dd94ba2501/generated_00.png?se=2025-02-12T17%3A57%3A32Z&sig=871OZAC1NVxojHVFSORQFZmVMFRmbuNOa5zo7brfft4%3D&ske=2025-02-14T01%3A52%3A27Z&skoid=09ba021e-c417-441c-b203-c81e5dcd7b7f&sks=b&skt=2025-02-07T01%3A52%3A27Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02'

# %%
Image.open(requests.get(image_url, stream=True).raw)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
