# %%
# Important: Don't forget to update this

AZURE_OPENAI_API_KEY = "***"
AZURE_OPENAI_ENDPOINT = "***"

GPT_DEPLOYMENT = "gpt-4o"
GPT_VERSION = "2024-08-01-preview"
DALLE_DEPLOYMENT = "dall-e-3"
DALLE_VERSION = "2024-02-01"

# %%
import requests
from PIL import Image
from IPython.display import display

from utils import create_openai_client, generate_image

# %%
dalle = create_openai_client(DALLE_VERSION, AZURE_OPENAI_API_KEY, AZURE_OPENAI_ENDPOINT)

# %%
prompt = "A minimal brand logo of brewing coffee on a coaster. brand name is 'CoC' short for Cup of Coffee"

# %%
image_url = generate_image(dalle, prompt, DALLE_DEPLOYMENT, '1024x1024', 'hd', 'vivid')
image_url
# Out:
# 'https://dalleproduse.blob.core.windows.net/private/images/108341f3-0c0d-4b3b-b46c-2ba84711bc1a/generated_00.png?se=2025-02-11T18%3A02%3A12Z&sig=43tq518E7I1y6AWZjhebJokYkmzgCk%2FdrpOT%2FazCppE%3D&ske=2025-02-17T03%3A17%3A03Z&skoid=09ba021e-c417-441c-b203-c81e5dcd7b7f&sks=b&skt=2025-02-10T03%3A17%3A03Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02'

# %%
Image.open(requests.get(image_url, stream=True).raw)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
